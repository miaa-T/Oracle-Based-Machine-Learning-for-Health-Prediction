# %% [raw]
# %script
# DROP TABLE diabetes_data PURGE;
#
# CREATE TABLE diabetes_data (
#     Pregnancies  NUMBER,
#     Glucose      NUMBER,
#     BloodPressure NUMBER,
#     SkinThickness NUMBER,
#     Insulin      NUMBER,
#     BMI          NUMBER,
#     DiabetesPedigreeFunction NUMBER,
#     Age          NUMBER,
#     Outcome      NUMBER
# );

# %% [raw]
# %script
# INSERT ALL
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (6, 148, 72, 35, 0, 33.6, 0.627, 50, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1, 85, 66, 29, 0, 26.6, 0.351, 31, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (8, 183, 64, 0, 0, 23.3, 0.672, 32, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1, 89, 66, 23, 94, 28.1, 0.167, 21, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (0, 137, 40, 35, 168, 43.1, 2.288, 33, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (5, 116, 74, 0, 0, 25.6, 0.201, 30, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (3, 78, 50, 32, 88, 31, 0.248, 26, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (10, 115, 0, 0, 0, 35.3, 0.134, 29, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (2, 197, 70, 45, 543, 30.5, 0.158, 53, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (8, 125, 96, 0, 0, 0, 0.232, 54, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (4, 110, 92, 0, 0, 37.6, 0.191, 30, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (10, 168, 74, 0, 0, 38, 0.537, 34, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (10, 139, 80, 0, 0, 27.1, 1.441, 57, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1, 189, 60, 23, 846, 30.1, 0.398, 59, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (5, 166, 72, 19, 175, 25.8, 0.587, 51, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (7, 100, 0, 0, 0, 30, 0.484, 32, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (0, 118, 84, 47, 230, 45.8, 0.551, 31, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (7, 107, 74, 0, 0, 29.6, 0.254, 31, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1, 103, 30, 38, 83, 43.3, 0.183, 33, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1, 115, 70, 30, 96, 34.6, 0.529, 32, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (3, 126, 88, 41, 235, 39.3, 0.704, 27, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (8, 99, 84, 0, 0, 35.4, 0.388, 50, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (7, 196, 90, 0, 0, 39.8, 0.451, 41, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (9, 119, 80, 35, 0, 29, 0.263, 29, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (11, 143, 94, 33, 146, 36.6, 0.254, 51, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (10, 125, 70, 26, 115, 31.1, 0.205, 41, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (7, 147, 76, 0, 0, 39.4, 0.257, 43, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1, 97, 66, 15, 140, 23.2, 0.487, 22, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (13, 145, 82, 19, 110, 22.2, 0.245, 57, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (5, 117, 92, 0, 0, 34.1, 0.337, 38, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (5, 109, 75, 26, 0, 36, 0.546, 60, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (3, 158, 76, 0, 0, 34.6, 0.851, 28, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (4, 103, 60, 33, 192, 24, 0.966, 33, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (11, 138, 72, 0, 0, 33.2, 0.42, 35, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (9, 102, 76, 37, 0, 32.9, 0.665, 46, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (2, 90, 68, 42, 0, 38.2, 0.503, 27, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (4, 111, 72, 47, 207, 37.1, 1.39, 56, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (3, 180, 64, 35, 70, 34, 0.271, 26, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (7, 133, 84, 0, 0, 40.2, 0.696, 37, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (7, 106, 92, 18, 0, 22.7, 0.235, 48, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (9, 171, 110, 24, 240, 45.4, 0.721, 54, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (7, 159, 64, 0, 0, 27.4, 0.294, 40, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (0, 180, 66, 39, 0, 42, 1.893, 25, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1, 146, 56, 0, 0, 29.7, 0.564, 29, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (2, 71, 70, 27, 0, 28, 0.586, 22, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (7, 103, 66, 32, 0, 39.1, 0.344, 31, 1)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (7, 105, 0, 0, 0, 0, 0.305, 24, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1, 103, 80, 11, 82, 19.4, 0.491, 22, 0)
#   INTO diabetes_data (Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1,
pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome) VALUES (1, 93, 70, 31, 0, 30.4, 0.315, 23, 0)
# SELECT 1 FROM DUAL;
# COMMIT;

# %% [raw]
# %script
# ALTER TABLE diabetes_data ADD (ID NUMBER);
#
# UPDATE diabetes_data SET ID = ROWNUM;
#
# ALTER TABLE diabetes_data ADD CONSTRAINT diabetes_data_pk PRIMARY KEY (ID);

# %% [raw]
# %script
# ALTER TABLE diabetes_data ADD (data_set VARCHAR2(10));
#
# UPDATE diabetes_data
# SET data_set = CASE WHEN DBMS_RANDOM.VALUE < 0.8 THEN 'TRAIN' ELSE 'TEST' END;
#
# SELECT data_set, COUNT(*) FROM diabetes_data GROUP BY data_set;

# %% [raw]
# %script
# BEGIN
#   DBMS_DATA_MINING.DROP_MODEL('DIABETES_MODEL');
# EXCEPTION
#   WHEN OTHERS THEN NULL;
# END;
# /
#
# BEGIN
#   EXECUTE IMMEDIATE 'DROP TABLE diabetes_settings';
# EXCEPTION
#   WHEN OTHERS THEN NULL;
# END;
# /
#
# CREATE TABLE diabetes_settings (
#     setting_name  VARCHAR2(30),
#     setting_value VARCHAR2(30)
# );
#
# INSERT INTO diabetes_settings (setting_name, setting_value) VALUES
#   ('ALGO_NAME', 'ALGO_DECISION_TREE');
#
#
# BEGIN
#   DBMS_DATA_MINING.CREATE_MODEL(
#     model_name          => 'DIABETES_MODEL',
#     mining_function     => DBMS_DATA_MINING.CLASSIFICATION,
#     data_table_name     => 'diabetes_data',
#     case_id_column_name => 'ID',
#     target_column_name  => 'Outcome',
#     settings_table_name => 'diabetes_settings',
#     data_schema_name    => USER
#   );
# END;
# /

# %% [raw]
# %script
# SELECT
#     Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome AS actual,
#     PREDICTION(DIABETES_MODEL USING
#         Pregnancies AS Pregnancies,
#         Glucose AS Glucose,
#         BloodPressure AS BloodPressure,
#         SkinThickness AS SkinThickness,
#         Insulin AS Insulin,
#         BMI AS BMI,
#         DiabetesPedigreeFunction AS DiabetesPedigreeFunction,
#         Age AS Age
#     ) AS predicted
# FROM diabetes_data
# WHERE data_set = 'TEST';

# %% [raw]
# %script
# SELECT
#     COUNT(*) AS total,
#     SUM(CASE WHEN Outcome = PREDICTION(DIABETES_MODEL USING
#         Pregnancies AS Pregnancies,
#         Glucose AS Glucose,
#         BloodPressure AS BloodPressure,
#         SkinThickness AS SkinThickness,
#         Insulin AS Insulin,
#         BMI AS BMI,
#         DiabetesPedigreeFunction AS DiabetesPedigreeFunction,
#         Age AS Age
#     ) THEN 1 ELSE 0 END) AS correct,
#     ROUND(100 * SUM(CASE WHEN Outcome = PREDICTION(DIABETES_MODEL USING
#         Pregnancies AS Pregnancies,
#         Glucose AS Glucose,
#         BloodPressure AS BloodPressure,
#         SkinThickness AS SkinThickness,
#         Insulin AS Insulin,
#         BMI AS BMI,
#         DiabetesPedigreeFunction AS DiabetesPedigreeFunction,
#         Age AS Age
#     ) THEN 1 ELSE 0 END) / COUNT(*), 2) AS accuracy_percent
# FROM diabetes_data
# WHERE data_set = 'TEST';

# %% [raw]
# %script
# SELECT model_name, mining_function, algorithm
# FROM user_mining_models
# WHERE model_name = 'DIABETES_MODEL';
